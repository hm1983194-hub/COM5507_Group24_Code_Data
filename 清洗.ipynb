# %%
import os

# 查看当前工作目录
print("当前工作目录:", os.getcwd())

# 更改工作目录到指定路径
new_path = r"D:\AImportant\留学\港城\course\Sem A\COM5507 Social Media Data\Group Project\Data"  # 替换为你想要的路径
os.chdir(new_path)

# 验证是否更改成功
print("更改后工作目录:", os.getcwd())

# 查看新目录下的文件
print("新目录下的文件:")
for file in os.listdir('.'):
    if file.endswith('.csv'):
        print(f"  📄 {file}")
# Out:
# 当前工作目录: C:\Users\86155\Desktop
# 更改后工作目录: D:\AImportant\留学\港城\course\Sem A\COM5507 Social Media Data\Group Project\Data
# 新目录下的文件:
#   📄 carousell_dimoo.csv
#   📄 carousell_labubu.csv
#   📄 carousell_molly.csv

# %%
import pandas as pd
import re

# 方法2：使用正斜杠（Windows也支持）
df = pd.read_csv("D:\AImportant\留学\港城\course\Sem A\COM5507 Social Media Data\Group Project\Data\carousell_molly.csv")
print(f"原始数据条数: {len(df)}")

# 其余代码相同...
def contains_molly_related(text):
    if pd.isna(text):
        return False
    
    text_lower = str(text).lower()
    
    if 'molly' not in text_lower:
        return False
    
    cleaned_text = re.sub(r'[^\w]', ' ', text_lower).strip()
    words = [word for word in cleaned_text.split() if len(word) > 2]
    
    if len(words) == 1 and words[0] == 'molly':
        return False
    
    return True

df_cleaned = df[df['商品名称'].apply(contains_molly_related)]

print(f"清洗后数据条数: {len(df_cleaned)}")
print(f"过滤掉了 {len(df) - len(df_cleaned)} 条数据")

# 保存结果
df_cleaned.to_csv("cleaned_molly_cleaned.csv", index=False, encoding="utf-8-sig")
print(f"✅ 清洗后的数据已保存到: cleaned_molly_cleaned.csv")
# Out:
# 原始数据条数: 10534
# 清洗后数据条数: 10216
# 过滤掉了 318 条数据
# ✅ 清洗后的数据已保存到: cleaned_molly_cleaned.csv

# %%
import pandas as pd
import re

# 方法2：使用正斜杠（Windows也支持）
df = pd.read_csv("D:\AImportant\留学\港城\course\Sem A\COM5507 Social Media Data\Group Project\Data\carousell_dimoo.csv")
print(f"原始数据条数: {len(df)}")

# 其余代码相同...
def contains_dimoo_related(text):
    if pd.isna(text):
        return False
    
    text_lower = str(text).lower()
    
    if 'dimoo' not in text_lower:
        return False
    
    cleaned_text = re.sub(r'[^\w]', ' ', text_lower).strip()
    words = [word for word in cleaned_text.split() if len(word) > 2]
    
    if len(words) == 1 and words[0] == 'dimoo':
        return False
    
    return True

df_cleaned = df[df['商品名称'].apply(contains_dimoo_related)]

print(f"清洗后数据条数: {len(df_cleaned)}")
print(f"过滤掉了 {len(df) - len(df_cleaned)} 条数据")

# 保存结果
df_cleaned.to_csv("cleaned_dimoo_cleaned.csv", index=False, encoding="utf-8-sig")
print(f"✅ 清洗后的数据已保存到: cleaned_dimoo_cleaned.csv")
# Out:
# 原始数据条数: 10536
# 清洗后数据条数: 9976
# 过滤掉了 560 条数据
# ✅ 清洗后的数据已保存到: cleaned_dimoo_cleaned.csv

# %%
import pandas as pd
import re

# 方法2：使用正斜杠（Windows也支持）
df = pd.read_csv("D:\AImportant\留学\港城\course\Sem A\COM5507 Social Media Data\Group Project\Data\carousell_labubu.csv")
print(f"原始数据条数: {len(df)}")

# 其余代码相同...
def contains_labubu_related(text):
    if pd.isna(text):
        return False
    
    text_lower = str(text).lower()
    
    if 'labubu' not in text_lower:
        return False
    
    cleaned_text = re.sub(r'[^\w]', ' ', text_lower).strip()
    words = [word for word in cleaned_text.split() if len(word) > 2]
    
    if len(words) == 1 and words[0] == 'labubu':
        return False
    
    return True

df_cleaned = df[df['商品名称'].apply(contains_labubu_related)]

print(f"清洗后数据条数: {len(df_cleaned)}")
print(f"过滤掉了 {len(df) - len(df_cleaned)} 条数据")

# 保存结果
df_cleaned.to_csv("cleaned_labubu_cleaned.csv", index=False, encoding="utf-8-sig")
print(f"✅ 清洗后的数据已保存到: cleaned_labubu_cleaned.csv")

# %%
import pandas as pd
import re

df = pd.read_csv("D:\AImportant\留学\港城\course\Sem A\COM5507 Social Media Data\Group Project\Data\carousell_skullpanda.csv")
print(f"原始数据条数: {len(df)}")

def contains_skullpanda_related(text):
    if pd.isna(text):
        return False
    
    text_lower = str(text).lower()
    
    if 'skullpanda' not in text_lower:
        return False
    
    cleaned_text = re.sub(r'[^\w]', ' ', text_lower).strip()
    words = [word for word in cleaned_text.split() if len(word) > 2]
    
    if len(words) == 1 and words[0] == 'skullpanda':
        return False
    
    return True

df_cleaned = df[df['商品名称'].apply(contains_skullpanda_related)]

print(f"清洗后数据条数: {len(df_cleaned)}")
print(f"过滤掉了 {len(df) - len(df_cleaned)} 条数据")

# 保存结果
df_cleaned.to_csv("cleaned_skullpanda_cleaned.csv", index=False, encoding="utf-8-sig")
print(f"✅ 清洗后的数据已保存到: cleaned_skullpanda_cleaned.csv")
# Out:
# 原始数据条数: 10528
# 清洗后数据条数: 10228
# 过滤掉了 300 条数据
# ✅ 清洗后的数据已保存到: cleaned_skullpanda_cleaned.csv

# %%
import pandas as pd
import re

df = pd.read_csv("D:\AImportant\留学\港城\course\Sem A\COM5507 Social Media Data\Group Project\Data\carousell_sweetbean.csv")
print(f"原始数据条数: {len(df)}")

def contains_sweetbean_related(text):
    """
    检查文本是否包含sweetbean或小甜豆相关内容
    仅剔除完全只有sweetbean或小甜豆的情况
    """
    if pd.isna(text):
        return False
    
    text_str = str(text)
    text_lower = text_str.lower()
    
    # 检查是否包含sweetbean或小甜豆
    has_sweetbean = 'sweetbean' in text_lower or 'sweet bean' in text_lower
    has_xiaotiandou = '小甜豆' in text_str
    
    # 如果两者都不包含，直接返回False
    if not has_sweetbean and not has_xiaotiandou:
        return False
    
    # 移除sweetbean和小甜豆关键词，检查是否还有其他内容
    temp_text = text_str
    
    # 移除sweetbean相关关键词
    temp_text = re.sub(r'sweetbean|sweet bean', '', temp_text, flags=re.IGNORECASE)
    # 移除小甜豆
    temp_text = temp_text.replace('小甜豆', '')
    
    # 清理文本，保留有意义的内容
    cleaned_temp = re.sub(r'[^a-zA-Z0-9\u4e00-\u9fff]', ' ', temp_text).strip()
    meaningful_words = [word for word in cleaned_temp.split() if len(word) > 1]
    
    # 如果移除关键词后没有其他有意义的内容，则过滤掉
    if not meaningful_words:
        return False
    
    return True

def debug_contains_sweetbean_related(text):
    """
    调试版本，显示处理过程
    """
    if pd.isna(text):
        print(f"DEBUG: {text} -> NaN")
        return False
    
    text_str = str(text)
    text_lower = text_str.lower()
    
    print(f"\nDEBUG 处理: {text_str}")
    
    # 检查是否包含sweetbean或小甜豆
    has_sweetbean = 'sweetbean' in text_lower or 'sweet bean' in text_lower
    has_xiaotiandou = '小甜豆' in text_str
    
    print(f"  - 包含sweetbean: {has_sweetbean}")
    print(f"  - 包含小甜豆: {has_xiaotiandou}")
    
    # 如果两者都不包含，直接返回False
    if not has_sweetbean and not has_xiaotiandou:
        print(f"  -> 不包含关键词，过滤")
        return False
    
    # 移除sweetbean和小甜豆关键词，检查是否还有其他内容
    temp_text = text_str
    
    # 移除sweetbean相关关键词
    temp_text = re.sub(r'sweetbean|sweet bean', '', temp_text, flags=re.IGNORECASE)
    # 移除小甜豆
    temp_text = temp_text.replace('小甜豆', '')
    
    print(f"  - 移除关键词后: '{temp_text}'")
    
    # 清理文本，保留有意义的内容
    cleaned_temp = re.sub(r'[^a-zA-Z0-9\u4e00-\u9fff]', ' ', temp_text).strip()
    meaningful_words = [word for word in cleaned_temp.split() if len(word) > 1]
    
    print(f"  - 有意义词汇: {meaningful_words}")
    
    # 如果移除关键词后没有其他有意义的内容，则过滤掉
    if not meaningful_words:
        print(f"  -> 没有其他内容，过滤")
        return False
    
    print(f"  -> 保留")
    return True

# 先测试几个被错误过滤的例子
test_examples = [
    "Sweet Bean 天使（已開包裝）",
    "Sweet Bean 聖誕節隱藏版公仔", 
    "Sweet Bean屬於你的節日系列-送出禮物",
    "Pop Mart Sweet Bean Angel's Blessing",
    "POP MART Sweet Bean Frozen Time Dessert Box",
    "sweetbean",  # 这个应该被过滤
    "小甜豆",     # 这个应该被过滤
    "sweet bean 123"  # 这个应该被过滤
]

print("=== 调试测试 ===")
for example in test_examples:
    result = debug_contains_sweetbean_related(example)
    print(f"最终结果: {result}")

print("\n" + "="*50)
print("开始正式过滤...")

# 应用过滤
df_cleaned = df[df['商品名称'].apply(contains_sweetbean_related)]

print(f"清洗后数据条数: {len(df_cleaned)}")
print(f"过滤掉了 {len(df) - len(df_cleaned)} 条数据")

# 显示被过滤掉的示例
df_filtered = df[~df.index.isin(df_cleaned.index)]
if not df_filtered.empty:
    print(f"\n被过滤掉的商品示例:")
    for i, (idx, row) in enumerate(df_filtered.head(10).iterrows()):
        print(f"示例 {i+1}: {row['商品名称']}")

# 显示保留的商品示例
if not df_cleaned.empty:
    print(f"\n保留的商品示例:")
    for i, (idx, row) in enumerate(df_cleaned.head(10).iterrows()):
        print(f"示例 {i+1}: {row['商品名称']}")

# 保存结果
df_cleaned.to_csv("cleaned_sweetbean.csv", index=False, encoding="utf-8-sig")
print(f"\n✅ 清洗后的数据已保存到: cleaned_sweetbean.csv")
# Out:
# 原始数据条数: 1048
# === 调试测试 ===
#
# DEBUG 处理: Sweet Bean 天使（已開包裝）
#   - 包含sweetbean: True
#   - 包含小甜豆: False
#   - 移除关键词后: ' 天使（已開包裝）'
#   - 有意义词汇: ['天使', '已開包裝']
#   -> 保留
# 最终结果: True
#
# DEBUG 处理: Sweet Bean 聖誕節隱藏版公仔
#   - 包含sweetbean: True
#   - 包含小甜豆: False
#   - 移除关键词后: ' 聖誕節隱藏版公仔'
#   - 有意义词汇: ['聖誕節隱藏版公仔']
#   -> 保留
# 最终结果: True
#
# DEBUG 处理: Sweet Bean屬於你的節日系列-送出禮物
#   - 包含sweetbean: True
#   - 包含小甜豆: False
#   - 移除关键词后: '屬於你的節日系列-送出禮物'
#   - 有意义词汇: ['屬於你的節日系列', '送出禮物']
#   -> 保留
# 最终结果: True
#
# DEBUG 处理: Pop Mart Sweet Bean Angel's Blessing
#   - 包含sweetbean: True
#   - 包含小甜豆: False
#   - 移除关键词后: 'Pop Mart  Angel's Blessing'
#   - 有意义词汇: ['Pop', 'Mart', 'Angel', 'Blessing']
#   -> 保留
# 最终结果: True
#
# DEBUG 处理: POP MART Sweet Bean Frozen Time Dessert Box
#   - 包含sweetbean: True
#   - 包含小甜豆: False
#   - 移除关键词后: 'POP MART  Frozen Time Dessert Box'
#   - 有意义词汇: ['POP', 'MART', 'Frozen', 'Time', 'Dessert', 'Box']
#   -> 保留
# 最终结果: True
#
# DEBUG 处理: sweetbean
# ...

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import re
import time
import json
from urllib.parse import urljoin
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

def scrape_labubu_directory():
    """
    专门爬取 labubu.directory 官方图鉴数据
    """
    base_url = "https://labubu.directory"
    series_url = "https://labubu.directory/zh/series"
    
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36',
        'Accept-Language': 'zh-CN,zh;q=0.9,en;q=0.8',
        'Referer': 'https://labubu.directory/'
    }
    
    try:
        print("正在访问系列页面...")
        response = requests.get(series_url, headers=headers)
        response.raise_for_status()
        soup = BeautifulSoup(response.content, 'html.parser')
        
        # 查找所有系列链接
        series_links = []
        
        # 尝试多种选择器来找到系列链接
        selectors = [
            'a[href*="/zh/series/"]',
            '.series-item a',
            '.collection-item a',
            '.grid a',
            'a.card'
        ]
        
        for selector in selectors:
            links = soup.select(selector)
            if links:
                print(f"使用选择器 '{selector}' 找到 {len(links)} 个系列")
                series_links.extend(links)
                break
        
        # 如果没找到，尝试更通用的方法
        if not series_links:
            all_links = soup.find_all('a', href=True)
            series_links = [link for link in all_links if '/zh/series/' in link['href']]
            print(f"通过通用方法找到 {len(series_links)} 个系列")
        
        # 去重并构建完整URL
        unique_series_links = []
        seen_urls = set()
        
        for link in series_links:
            href = link['href']
            if href.startswith('/'):
                full_url = urljoin(base_url, href)
            else:
                full_url = href
            
            if full_url not in seen_urls and '/zh/series/' in full_url:
                seen_urls.add(full_url)
                series_name = link.get_text(strip=True) or "未知系列"
                unique_series_links.append({
                    'url': full_url,
                    'name': series_name
                })
        
        print(f"去重后得到 {len(unique_series_links)} 个系列")
        
        # 爬取每个系列的商品
        all_products = []
        
        for i, series in enumerate(unique_series_links, 1):
            print(f"正在爬取系列 {i}/{len(unique_series_links)}: {series['name']}")
            
            try:
                series_response = requests.get(series['url'], headers=headers)
                series_response.raise_for_status()
                series_soup = BeautifulSoup(series_response.content, 'html.parser')
                
                # 查找系列中的商品
                product_selectors = [
                    '.product-card',
                    '.item-card', 
                    '.character-card',
                    '.grid > div',  # 网格布局中的项目
                    '[class*="card"]'  # 任何包含card的类
                ]
                
                products_in_series = []
                for selector in product_selectors:
                    products = series_soup.select(selector)
                    if products:
                        print(f"  使用选择器 '{selector}' 找到 {len(products)} 个商品")
                        products_in_series = products
                        break
                
                # 提取每个商品的信息
                for product in products_in_series:
                    try:
                        # 提取商品名称
                        name_selectors = [
                            '.product-name', '.character-name', '.name',
                            'h3', 'h4', '.title', '[class*="name"]',
                            '.text-lg', '.font-bold'  # 常见的大字粗体文本
                        ]
                        
                        product_name = None
                        for name_selector in name_selectors:
                            name_element = product.select_one(name_selector)
                            if name_element:
                                product_name = name_element.get_text(strip=True)
                                break
                        
                        # 如果还没找到，尝试获取整个卡片的文本
                        if not product_name:
                            product_name = product.get_text(strip=True)
                            # 清理文本，只取前50个字符作为名称
                            if len(product_name) > 50:
                                product_name = re.sub(r'\s+', ' ', product_name[:50] + "...")
                        
                        # 提取图片
                        img_selectors = ['img', '.product-image', '.character-image']
                        img_url = None
                        for img_selector in img_selectors:
                            img_element = product.select_one(img_selector)
                            if img_element and img_element.get('src'):
                                img_src = img_element.get('src')
                                if img_src.startswith('//'):
                                    img_url = 'https:' + img_src
                                elif img_src.startswith('/'):
                                    img_url = urljoin(base_url, img_src)
                                else:
                                    img_url = img_src
                                break
                        
                        if product_name and len(product_name) > 1:
                            all_products.append({
                                '官方名称': product_name,
                                '系列名称': series['name'],
                                '图片URL': img_url,
                                '系列URL': series['url']
                            })
                            
                    except Exception as e:
                        print(f"    提取商品时出错: {e}")
                        continue
                
                # 礼貌性延迟
                time.sleep(1)
                
            except Exception as e:
                print(f"爬取系列 {series['name']} 时出错: {e}")
                continue
        
        print(f"总共爬取到 {len(all_products)} 个官方商品")
        return all_products
        
    except Exception as e:
        print(f"爬取过程中出错: {e}")
        return []

# 新增：繁简转换函数（在匹配前使用）
def convert_traditional_to_simplified(text):
    """
    将繁体中文转换为简体中文
    """
    if pd.isna(text):
        return text
        
    trad_to_simp = {
        '可口可樂': '可口可乐', '骷髏': '骷髅', '萬聖節': '万圣节', '聖誕': '圣诞',
        '復活節': '复活节', '音樂': '音乐', '劇場': '剧场', '冒險': '冒险', '海洋': '海洋',
        '森林': '森林', '動物': '动物', '童話': '童话', '魔法': '魔法', '公主': '公主',
        '王子': '王子', '騎士': '骑士', '武士': '武士', '忍者': '忍者', '怪獸': '怪兽',
        '恐龍': '恐龙', '太空': '太空', '宇宙': '宇宙', '星星': '星星', '月亮': '月亮',
        '太陽': '太阳', '彩虹': '彩虹', '雲朵': '云朵', '雨滴': '雨滴', '雪花': '雪花',
        '禮物': '礼物', '愛心': '爱心', '天使': '天使', '魔鬼': '魔鬼', '精靈': '精灵',
        '幽靈': '幽灵', '巫師': '巫师', '南瓜': '南瓜', '糖果': '糖果', '禮服': '礼服',
        '皇冠': '皇冠', '寶石': '宝石', '珍珠': '珍珠', '鑽石': '钻石', '黃金': '黄金',
        '白銀': '白银', '銅牌': '铜牌', '獎盃': '奖杯', '獎牌': '金牌', '冠軍': '冠军',
        '亞軍': '亚军', '季軍': '季军', '比賽': '比赛', '運動': '运动', '籃球': '篮球',
        '足球': '足球', '網球': '网球', '棒球': '棒球', '游泳': '游泳', '滑雪': '滑雪',
        '衝浪': '冲浪', '潛水': '潜水', '釣魚': '钓鱼', '露營': '露营', '旅行': '旅行',
        '一點': '一点', '兩點': '两点', '三點': '三点', '四點': '四点', '五點': '五点'
    }
    
    text_str = str(text)
    for trad, simp in trad_to_simp.items():
        text_str = text_str.replace(trad, simp)
    return text_str

def enhanced_text_matching(df_products, df_official):
    """
    增强的文本匹配算法，专门针对Labubu商品
    """
    
    def traditional_to_simplified(text):
        """
        简单的繁简转换函数
        可以添加更多常见的繁简对应词
        """
        trad_to_simp = {
            '可口可樂': '可口可乐',
            '骷髏': '骷髅',
            '萬聖節': '万圣节',
            '聖誕': '圣诞',
            '復活節': '复活节',
            '音樂': '音乐',
            '劇場': '剧场',
            '冒險': '冒险',
            '海洋': '海洋',
            '森林': '森林',
            '動物': '动物',
            '童話': '童话',
            '魔法': '魔法',
            '公主': '公主',
            '王子': '王子',
            '騎士': '骑士',
            '武士': '武士',
            '忍者': '忍者',
            '怪獸': '怪兽',
            '恐龍': '恐龙',
            '太空': '太空',
            '宇宙': '宇宙',
            '星星': '星星',
            '月亮': '月亮',
            '太陽': '太阳',
            '彩虹': '彩虹',
            '雲朵': '云朵',
            '雨滴': '雨滴',
            '雪花': '雪花'
        }
        
        for trad, simp in trad_to_simp.items():
            text = text.replace(trad, simp)
        return text
    
    def labubu_text_preprocess(text):
        """专门针对Labubu商品的文本预处理"""
        if pd.isna(text):
            return ""
        
        text = str(text).lower()
        
        # 繁简转换
        text = traditional_to_simplified(text)
        
        # 保留关键信息：数字、中文、英文、空格、点号（用于版本号）
        # 扩展字符集，包含更多可能的中文标点
        text = re.sub(r'[^\w\s\.\·\-\u4e00-\u9fff]', '', text)
        
        # 处理常见的符号变体
        text = re.sub(r'[·・]', '', text)  # 中点符号
        
        # Labubu特定的停用词 - 减少停用词数量，保留更多关键词
        labubu_stop_words = {
            'pop', 'mart', 'labubu', 'the', 'monsters', '系列', '款', '版', 
            '正版', '全新', '未拆', '现货', '包邮', '特价', '优惠', '出售',
            '转让', '包正', '保证', '正品', 'popmart', 'monster', '手办',
            '盲盒', '模型', '玩具', '公仔'
        }
        
        words = text.split()
        filtered_words = [word for word in words if word not in labubu_stop_words and len(word) > 0]
        
        # 如果过滤后为空，返回原始文本的简化版本
        if not filtered_words:
            # 只移除标点符号，保留所有词汇
            simple_text = re.sub(r'[^\w\s\u4e00-\u9fff]', '', str(text))
            return simple_text.strip()
        
        return ' '.join(filtered_words)
    
    print("正在预处理文本...")
    df_products['清洗名称'] = df_products['商品名称'].apply(labubu_text_preprocess)
    df_official['清洗官方名称'] = df_official['官方名称'].apply(labubu_text_preprocess)
    
    # 添加调试信息
    print("\n=== 预处理示例 ===")
    for i, (orig, cleaned) in enumerate(zip(df_products['商品名称'].head(5), df_products['清洗名称'].head(5))):
        print(f"原始: {orig} -> 清洗: {cleaned}")
    
    # 使用字符级别的TF-IDF，更适合短文本匹配
    vectorizer = TfidfVectorizer(
        analyzer='char_wb',  # 字符级别的n-gram，尊重单词边界
        ngram_range=(1, 3),  # 调整为1到3个字符的n-gram，更好地处理短词
        min_df=1,
        max_features=10000,
        lowercase=False  # 不转换为小写，保留原始大小写信息（因为我们已经统一转小写了）
    )
    
    # 合并所有文本进行训练
    all_texts = list(df_products['清洗名称']) + list(df_official['清洗官方名称'])
    vectorizer.fit(all_texts)
    
    products_tfidf = vectorizer.transform(df_products['清洗名称'])
    official_tfidf = vectorizer.transform(df_official['清洗官方名称'])
    
    # 计算相似度矩阵
    similarity_matrix = cosine_similarity(products_tfidf, official_tfidf)
    
    # 找到最佳匹配
    matches = []
    for i, product_row in df_products.iterrows():
        best_match_idx = np.argmax(similarity_matrix[i])
        best_score = similarity_matrix[i][best_match_idx]
        
        # 动态阈值：对于包含关键字的商品使用更宽松的阈值
        product_text = product_row['清洗名称']
        has_keywords = any(keyword in product_text for keyword in ['可口可乐', 'coca', 'cola', '可乐'])
        
        threshold = 0.1 if has_keywords else 0.15  # 对关键词商品使用更低的阈值
        
        if best_score > threshold:
            official_match = df_official.iloc[best_match_idx]
            matches.append({
                '商品名称': product_row['商品名称'],
                '匹配官方名称': official_match['官方名称'],
                '匹配系列': official_match['系列名称'],
                '匹配图片URL': official_match.get('图片URL', ''),
                '匹配度': round(best_score, 3),
                '是否匹配成功': True
            })
        else:
            matches.append({
                '商品名称': product_row['商品名称'],
                '匹配官方名称': '未匹配到官方名称',
                '匹配系列': '未分类',
                '匹配图片URL': '',
                '匹配度': round(best_score, 3),
                '是否匹配成功': False
            })
    
    return pd.DataFrame(matches)

# 新增函数：基于关键词的补充匹配
def keyword_based_matching(df_final, df_official):
    """
    对TF-IDF未匹配成功的商品进行基于关键词的补充匹配
    """
    # 构建关键词到系列的映射
    keyword_to_series = {}
    for _, row in df_official.iterrows():
        series_name = row['系列名称']
        official_name = row['官方名称']
        
        # 从系列名称和官方名称中提取关键词
        keywords = set()
        
        # 系列名称关键词
        series_words = re.findall(r'[\u4e00-\u9fff]+|[a-zA-Z]+', str(series_name))
        keywords.update([word.lower() for word in series_words if len(word) > 1])
        
        # 官方名称关键词
        official_words = re.findall(r'[\u4e00-\u9fff]+|[a-zA-Z]+', str(official_name))
        keywords.update([word.lower() for word in official_words if len(word) > 1])
        
        for keyword in keywords:
            if keyword not in ['labubu', '系列', '款', '版']:  # 排除通用词
                if keyword not in keyword_to_series:
                    keyword_to_series[keyword] = []
                if series_name not in keyword_to_series[keyword]:
                    keyword_to_series[keyword].append(series_name)
    
    print(f"构建了 {len(keyword_to_series)} 个关键词到系列的映射")
    
    # 对未匹配的商品进行关键词匹配
    unmatched_df = df_final[df_final['是否匹配成功'] == False].copy()
    matched_count = 0
    
    for idx, row in unmatched_df.iterrows():
        product_name = str(row['商品名称']).lower()
        product_cleaned = str(row.get('清洗名称', '')).lower()
        
        best_series = None
        best_score = 0
        
        # 检查所有关键词
        for keyword, series_list in keyword_to_series.items():
            if len(keyword) < 2:  # 跳过太短的关键词
                continue
                
            # 检查商品名称中是否包含关键词
            if keyword in product_name or keyword in product_cleaned:
                for series in series_list:
                    # 简单的包含匹配
                    score = len(keyword) / len(product_name)
                    if score > best_score:
                        best_score = score
                        best_series = series
        
        # 如果找到匹配且置信度足够高
        if best_series and best_score > 0.3:
            # 找到对应的官方记录
            official_match = df_official[df_official['系列名称'] == best_series].iloc[0]
            df_final.loc[idx, '匹配官方名称'] = official_match['官方名称']
            df_final.loc[idx, '匹配系列'] = best_series
            df_final.loc[idx, '匹配图片URL'] = official_match.get('图片URL', '')
            df_final.loc[idx, '匹配度'] = round(best_score, 3)
            df_final.loc[idx, '是否匹配成功'] = True
            df_final.loc[idx, '匹配方式'] = '关键词匹配'
            matched_count += 1
    
    print(f"通过关键词匹配成功匹配了 {matched_count} 个商品")
    return df_final

# 新增：凌晨关键词后处理函数
def post_process_morning_keywords(df_final):
    """
    在匹配完成后，检查未匹配但包含凌晨关键词的商品，将其分类为凌晨一点系列
    """
    # 查找未匹配成功但包含凌晨关键词的商品
    morning_keywords = ['凌晨', '1am', '1:00', '01:00', '一點', '一点']
    pattern = '|'.join(morning_keywords)
    
    unmatched_with_morning = df_final[
        (df_final['是否匹配成功'] == False) & 
        (df_final['商品名称'].str.contains(pattern, case=False, na=False))
    ]
    
    if not unmatched_with_morning.empty:
        print(f"发现 {len(unmatched_with_morning)} 个未匹配但包含凌晨关键词的商品，将其分类为凌晨一点系列")
        
        for idx in unmatched_with_morning.index:
            df_final.loc[idx, '匹配系列'] = '凌晨一点系列'
            df_final.loc[idx, '匹配官方名称'] = '凌晨一点系列（后处理匹配）'
            df_final.loc[idx, '匹配度'] = 1.0
            df_final.loc[idx, '是否匹配成功'] = True
            if '匹配方式' in df_final.columns:
                df_final.loc[idx, '匹配方式'] = '凌晨关键词后处理'
            
            print(f"✅ 后处理匹配: {df_final.loc[idx, '商品名称']} -> 凌晨一点系列")
    
    return df_final

# 主程序
def main():
    # 读取商品数据
    df_products = pd.read_csv(r"D:\AImportant\留学\港城\course\Sem A\COM5507 Social Media Data\Group Project\Data\cleaned_labubu.csv")
    print(f"加载了 {len(df_products)} 个商品数据")
    
    # 新增：在匹配前将商品名称列由繁体转换为简体
    print("正在将商品名称由繁体转换为简体...")
    df_products['商品名称'] = df_products['商品名称'].apply(convert_traditional_to_simplified)
    print("✅ 商品名称繁简转换完成")
    
    # 显示转换后的示例
    print("\n=== 繁简转换示例 ===")
    for i, name in enumerate(df_products['商品名称'].head(5)):
        print(f"示例 {i+1}: {name}")
    
    # 爬取官方图鉴数据
    print("开始爬取官方图鉴数据...")
    official_products = scrape_labubu_directory()
    
    if not official_products:
        print("未能爬取到官方图鉴数据，请检查网络连接或网站结构")
        return
    
    # 创建官方商品DataFrame
    df_official = pd.DataFrame(official_products)
    
    # 去重
    df_official = df_official.drop_duplicates(subset=['官方名称'])
    print(f"去重后官方商品数量: {len(df_official)}")
    
    # 保存官方图鉴数据
    official_save_path = r"D:\AImportant\留学\港城\course\Sem A\COM5507 Social Media Data\Group Project\Data\catalog_labubu.csv"
    df_official.to_csv(official_save_path, index=False, encoding="utf-8-sig")
    print(f"✅ 官方图鉴数据已保存到: {official_save_path}")
    
    # 显示一些官方商品示例
    print("\n=== 官方商品示例 ===")
    for i, row in df_official.head(10).iterrows():
        print(f"{i+1}. {row['官方名称']} - {row['系列名称']}")
    
    # 进行匹配
    print("\n正在进行商品匹配...")
    df_matches = enhanced_text_matching(df_products, df_official)
    
    # 合并结果
    df_final = df_products.merge(df_matches, on='商品名称', how='left')
    
    # 添加匹配方式列
    df_final['匹配方式'] = 'TF-IDF匹配'
    
    # 进行关键词补充匹配
    print("\n正在进行关键词补充匹配...")
    df_final = keyword_based_matching(df_final, df_official)
    
    # 新增：凌晨关键词后处理
    print("\n正在进行凌晨关键词后处理...")
    df_final = post_process_morning_keywords(df_final)
    
    # 分析匹配结果
    match_stats = df_final['是否匹配成功'].value_counts()
    print(f"\n=== 匹配结果统计 ===")
    print(f"成功匹配: {match_stats.get(True, 0)} 件商品")
    print(f"未成功匹配: {match_stats.get(False, 0)} 件商品")
    if len(df_final) > 0:
        success_rate = match_stats.get(True, 0) / len(df_final) * 100
        print(f"匹配成功率: {success_rate:.1f}%")
    
    # 显示匹配方式统计
    if '匹配方式' in df_final.columns:
        method_stats = df_final[df_final['是否匹配成功'] == True]['匹配方式'].value_counts()
        print(f"\n=== 匹配方式统计 ===")
        for method, count in method_stats.items():
            print(f"{method}: {count}件")
    
    # 显示匹配示例
    print("\n=== 成功匹配示例 ===")
    successful_matches = df_final[df_final['是否匹配成功'] == True].head(10)
    for _, row in successful_matches.iterrows():
        match_method = row.get('匹配方式', 'TF-IDF匹配')
        print(f"商品: {row['商品名称']}")
        print(f"官方: {row['匹配官方名称']}")
        print(f"系列: {row['匹配系列']} (匹配度: {row['匹配度']}, 方式: {match_method})")
        print("---")
    
    # 显示未匹配示例（用于改进算法）
    print("\n=== 未匹配示例（需要改进）===")
    failed_matches = df_final[df_final['是否匹配成功'] == False].head(5)
    for _, row in failed_matches.iterrows():
        print(f"未匹配商品: {row['商品名称']} (最高匹配度: {row['匹配度']})")
    
    # 保存最终结果
    final_save_path = r"D:\AImportant\留学\港城\course\Sem A\COM5507 Social Media Data\Group Project\Data\matches_labubu.csv"
    df_final.to_csv(final_save_path, index=False, encoding="utf-8-sig")
    print(f"\n✅ 最终匹配结果已保存到: {final_save_path}")
    
    # 生成系列统计
    if not df_final[df_final['是否匹配成功'] == True].empty:
        series_stats = df_final[df_final['是否匹配成功'] == True]['匹配系列'].value_counts()
        print(f"\n=== 各系列商品数量 ===")
        for series, count in series_stats.head(10).items():
            print(f"{series}: {count}件")

if __name__ == "__main__":
    main()
# Out:
# 加载了 6684 个商品数据
# 正在将商品名称由繁体转换为简体...
# ✅ 商品名称繁简转换完成
#
# === 繁简转换示例 ===
# 示例 1: labubu 凌晨一点 美夢時間
# 示例 2: POP MART Labubu 金蛇報喜 金蛇賀歲 毛絨門掛
# 示例 3: 【好評過百/誠信賣家】THE MONSTER - 全新未拆盒機款/拆盒未拆袋款/礼物首選/心底密碼系列/mini labubu 4.0/ A-M & N-Z （價錢優惠請睇詳情）
# 示例 4: Pop Mart LABUBU 全新 荔枝莓莓 盲盒 The Monsters Exciting Macaron Lychee Berry
# 示例 5: POPMART Labubu 坐坐
# 开始爬取官方图鉴数据...
# 正在访问系列页面...
# 使用选择器 'a[href*="/zh/series/"]' 找到 72 个系列
# 去重后得到 72 个系列
# 正在爬取系列 1/72: [新] Labubu Why So Serious 万圣节系列2025.10
#   使用选择器 '.grid > div' 找到 23 个商品
# 正在爬取系列 2/72: [新] Labubu 心底秘密系列2025.08
#   使用选择器 '.grid > div' 找到 47 个商品
# 正在爬取系列 3/72: Labubu FALL IN WILD Series2024.04
#   使用选择器 '.grid > div' 找到 7 个商品
# 正在爬取系列 4/72: Labubu 快乐万圣节派对系列2024.10
#   使用选择器 '.grid > div' 找到 11 个商品
# 正在爬取系列 5/72: LABUBU × PRONOUNCE - WINGS OF FORTUNE Series2024.10
#   使用选择器 '.grid > div' 找到 6 个商品
# 正在爬取系列 6/72: Labubu Time to Chill2022.10
#   使用选择器 '.grid > div' 找到 6 个商品
# 正在爬取系列 7/72: Labubu Angel In Clouds2024.10
#   使用选择器 '.grid > div' 找到 4 个商品
# ...

# %%
import pandas as pd

def remove_duplicate_data(df):
    """
    剔除商品名称、价格、发布用户、发布时间、商品链接和爬取时间完全一样的数据
    """
    print("\n=== 开始数据去重 ===")
    original_count = len(df)
    print(f"去重前数据量: {original_count}")
    
    # 定义去重的列
    duplicate_columns = ['商品名称', '价格', '发布用户', '发布时间', '商品链接', '爬取时间']
    
    # 检查哪些列实际存在于DataFrame中
    available_columns = [col for col in duplicate_columns if col in df.columns]
    print(f"用于去重的列: {available_columns}")
    
    # 容错：如果没有可用去重列，直接返回原始数据
    if not available_columns:
        print("⚠️  未找到任何可用的去重列，返回原始数据")
        return df
    
    # 检查重复数据
    duplicate_rows = df[df.duplicated(subset=available_columns, keep=False)]
    if not duplicate_rows.empty:
        print(f"发现 {len(duplicate_rows)} 条重复数据")
        print("\n重复数据示例:")
        for i, (idx, row) in enumerate(duplicate_rows.head(3).iterrows()):
            print(f"示例 {i+1}:")
            for col in available_columns:
                print(f"  {col}: {row[col]}")
            print("  ---")
    else:
        print("✅ 未发现重复数据")
    
    # 执行去重（保留第一条记录）
    df_deduplicated = df.drop_duplicates(subset=available_columns, keep='first')
    final_count = len(df_deduplicated)
    
    # 输出去重统计
    removed_count = original_count - final_count
    print(f"\n去重后数据量: {final_count}")
    print(f"移除的重复数据: {removed_count} 条")
    print(f"去重率: {((removed_count / original_count) * 100):.2f}%" if original_count > 0 else "0.00%")
    print("=== 去重完成 ===")
    
    return df_deduplicated

def filter_unmatched_data(df):
    """
    删除匹配系列为「未匹配」或「未分类」的数据（可根据实际字段值调整）
    """
    print("\n=== 开始过滤未匹配数据 ===")
    # 检查是否存在「匹配系列」列
    if '匹配系列' not in df.columns:
        print("⚠️  数据中未找到『匹配系列』列，跳过过滤步骤")
        return df
    
    # 定义未匹配的关键词（根据实际数据调整，常见值：未匹配、未分类、未匹配到系列）
    unmatched_keywords = ['未匹配', '未分类', '未匹配到系列', '未匹配到官方名称']
    
    # 统计未匹配数据量
    unmatched_mask = df['匹配系列'].isin(unmatched_keywords)
    unmatched_count = unmatched_mask.sum()
    total_count = len(df)
    
    print(f"过滤前数据量: {total_count} 条")
    print(f"未匹配数据量（匹配系列为 {unmatched_keywords}）: {unmatched_count} 条")
    
    # 过滤未匹配数据（保留匹配成功的数据）
    df_filtered = df[~unmatched_mask].reset_index(drop=True)
    filtered_count = len(df_filtered)
    
    print(f"过滤后数据量: {filtered_count} 条")
    print(f"移除的未匹配数据: {total_count - filtered_count} 条")
    print("=== 过滤未匹配数据完成 ===")
    
    return df_filtered

def main():
    # 1. 读取商品数据（添加错误处理）
    raw_data_path = r"D:\AImportant\留学\港城\course\Sem A\COM5507 Social Media Data\Group Project\Data\matches_labubu.csv"
    try:
        df_products = pd.read_csv(raw_data_path)
        print(f"✅ 成功加载商品数据，共 {len(df_products)} 条")
        print(f"数据包含列: {list(df_products.columns)}")
    except Exception as e:
        print(f"❌ 读取商品数据失败: {e}")
        return
    
    # 2. 数据去重
    df_deduplicated = remove_duplicate_data(df_products)
    
    # 3. 过滤未匹配数据（新增步骤：删除匹配系列为「未匹配」的数据）
    df_final = filter_unmatched_data(df_deduplicated)
    
    # 4. 保存最终结果（去重+过滤后的有效数据）
    final_save_path = r"D:\AImportant\留学\港城\course\Sem A\COM5507 Social Media Data\Group Project\Data\matched_labubu.csv"
    try:
        df_final.to_csv(final_save_path, index=False, encoding="utf-8-sig")
        print(f"\n✅ 最终结果已保存到: {final_save_path}")
        print(f"✅ 最终有效数据量: {len(df_final)} 条（去重+过滤未匹配后）")
    except Exception as e:
        print(f"❌ 保存数据失败: {e}")

# 执行主函数
if __name__ == "__main__":
    main()
# Out:
# ✅ 成功加载商品数据，共 13962 条
# 数据包含列: ['商品名称', '价格', '发布用户', '发布时间', '商品链接', '爬取时间', '清洗名称', '匹配官方名称', '匹配系列', '匹配图片URL', '匹配度', '是否匹配成功', '匹配方式']
#
# === 开始数据去重 ===
# 去重前数据量: 13962
# 用于去重的列: ['商品名称', '价格', '发布用户', '发布时间', '商品链接', '爬取时间']
# 发现 11919 条重复数据
#
# 重复数据示例:
# 示例 1:
#   商品名称: POP MART The Monsters Labubu 坐坐派對
#   价格: HK$120
#   发布用户: applepiie_
#   发布时间: 39 分鐘前
#   商品链接: https://www.carousell.com.hk/p/pop-mart-the-monsters-labubu-%E5%9D%90%E5%9D%90%E6%B4%BE%E5%B0%8D-1397749805/?t-id=Dg8pv0XwWo_1763803800169&t-referrer_browse_type=search_results&t-referrer_page_type=search&t-referrer_request_id=GFPyBKWWGNFP63Cq&t-referrer_search_query=labubu&t-referrer_sort_by=popular&t-tap_index=12
#   爬取时间: 2025-11-22 17:31:15
#   ---
# 示例 2:
#   商品名称: POP MART The Monsters Labubu 坐坐派對
#   价格: HK$120
#   发布用户: applepiie_
#   发布时间: 39 分鐘前
# ...

# %%
# dimoo清洗
import pandas as pd
import requests
from bs4 import BeautifulSoup
import re
import time
import json
from urllib.parse import urljoin
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import os
import datetime

# Dimoo系列配置
DIMOO_SERIES = [
    "Dimoo 如果今天星期八系列手办",
    "Dimoo心动特调系列（软脸毛绒钥匙扣盲盒）",
    "Dimoo侏罗纪世界系列（公仔）",
    "Dimoo 自然的形状系列（公仔）",
    "Dimoo WORLD × 迪士尼系列（公仔）",
    "Dimoo 梦里梦外系列（公仔）",
    "Dimoo 云陪伴系列（棉花娃娃）",
    "Dimoo 在你身边系列（公仔）",
    "Dimoo 动物王国系列（公仔）",
    "Dimoo 今晚不准睡系列（公仔）",
    "Dimoo 经典复刻系列（公仔）",
    "Dimoo 时光漫游系列（公仔）",
    "Dimoo 水族馆系列（公仔）",
    "Dimoo 去哪儿系列（公仔）",
    "Dimoo 宅宅系列系列（公仔）",
    "Dimoo 森林之夜系列（公仔）",
    "Dimoo 星座系列（公仔）"
]

def create_dimoo_official_data():
    """
    创建Dimoo官方系列数据
    """
    official_products = []
    
    for series_name in DIMOO_SERIES:
        # 为每个系列创建几个代表性的商品
        base_name = series_name.split('（')[0].split('系列')[0].strip()
        
        # 根据系列名称创建不同的商品变体
        if '星期八' in series_name:
            products = [f"{base_name} 纽扣开花", f"{base_name} 想要晴天", f"{base_name} 做雕塑",f"{base_name} 袜子小狗",f"{base_name} 和金鱼通电话",f"{base_name} 看漫画",f"{base_name} 快乐洗澡",f"{base_name} 溜气球鸭",f"{base_name} 睡大觉",f"{base_name} 思考人生",f"{base_name} 云层上跳舞",f"{base_name} 解锁时间",f"{base_name} 日历不听话"]
        elif '心动特调' in series_name:
            products = [f"{base_name} 生椰拿铁", f"{base_name} 海盐厚乳", f"{base_name} 焦糖奶咖",f"{base_name} 红茶冷萃",f"{base_name} 西柚美式",f"{base_name} 馥郁摩卡",f"{base_name} 心意浓缩"]
        elif '侏罗纪' in series_name:
            products = [f"{base_name} 龙蛋", f"{base_name} 幼龙", f"{base_name} 成长记录员",f"{base_name} 球形游览车",f"{base_name} 腕龙",f"{base_name} 乐园观光车",f"{base_name} 恐龙",f"{base_name} 翼龙",f"{base_name} 恐龙"]
        elif '自然的形状' in series_name:
            products = [f"{base_name} 看见", f"{base_name} 水滴", f"{base_name} 树叶"]
        elif '迪士尼' in series_name:
            products = [f"{base_name} 米奇", f"{base_name} 唐老鸭", f"{base_name} 小熊维尼"]
        elif '梦里梦外' in series_name:
            products = [f"{base_name} 美梦", f"{base_name} 梦境", f"{base_name} 梦游"]
        elif '云陪伴' in series_name:
            products = [f"{base_name} 晴天", f"{base_name} 雨天", f"{base_name} 彩虹"]
        elif '在你身边' in series_name:
            products = [f"{base_name} 陪伴", f"{base_name} 守护", f"{base_name} 依靠"]
        elif '动物王国' in series_name:
            products = [f"{base_name} 狮子", f"{base_name} 大象", f"{base_name} 长颈鹿"]
        elif '今晚不准睡' in series_name:
            products = [f"{base_name} 熬夜", f"{base_name} 失眠", f"{base_name} 夜猫子"]
        elif '经典复刻' in series_name:
            products = [f"{base_name} 复古", f"{base_name} 怀旧", f"{base_name} 经典"]
        elif '时光漫游' in series_name:
            products = [f"{base_name} 过去", f"{base_name} 现在", f"{base_name} 未来"]
        elif '水族馆' in series_name:
            products = [f"{base_name} 鲸鱼", f"{base_name} 海豚", f"{base_name} 水母"]
        elif '去哪儿' in series_name:
            products = [f"{base_name} 旅行", f"{base_name} 探险", f"{base_name} 漫游"]
        elif '宅宅系列' in series_name:
            products = [f"{base_name} 宅家", f"{base_name} 游戏", f"{base_name} 放松"]
        elif '森林之夜' in series_name:
            products = [f"{base_name} 猫头鹰", f"{base_name} 萤火虫", f"{base_name} 月光"]
        elif '星座' in series_name:
            products = [f"{base_name} 白羊座", f"{base_name} 金牛座", f"{base_name} 双子座"]
        else:
            products = [f"{base_name} 标准款", f"{base_name} 特别款", f"{base_name} 隐藏款"]
        
        for product_name in products:
            official_products.append({
                '官方名称': product_name,
                '系列名称': series_name,
                '图片URL': '',
                '系列URL': ''
            })
    
    return official_products

def convert_traditional_to_simplified(text):
    """
    将繁体中文转换为简体中文
    """
    if pd.isna(text):
        return text
        
    trad_to_simp = {
        '星期八': '星期八', '心動': '心动', '特調': '特调', '侏羅紀': '侏罗纪',
        '世界': '世界', '自然': '自然', '形狀': '形状', '夢裡': '梦里', '夢外': '梦外',
        '雲陪伴': '云陪伴', '棉花': '棉花', '娃娃': '娃娃', '動物': '动物', '王國': '王国',
        '經典': '经典', '復刻': '复刻', '時光': '时光', '漫遊': '漫游', '水族館': '水族馆',
        '去哪兒': '去哪儿', '宅宅': '宅宅', '森林': '森林', '之夜': '之夜', '星座': '星座',
        '鑰匙': '钥匙', '扣盲': '扣盲', '盒': '盒', '公仔': '公仔', '手辦': '手办',
        '軟臉': '软脸', '毛絨': '毛绒', '迪士尼': '迪士尼', '陪伴': '陪伴', '不准': '不准',
        '睡覺': '睡觉', '復古': '复古', '懷舊': '怀旧', '旅行': '旅行', '探險': '探险',
        '遊戲': '游戏', '放鬆': '放松', '貓頭鷹': '猫头鹰', '螢火蟲': '萤火虫', '月光': '月光'
    }
    
    text_str = str(text)
    for trad, simp in trad_to_simp.items():
        text_str = text_str.replace(trad, simp)
    return text_str

def enhanced_dimoo_matching(df_products, df_official):
    """
    增强的文本匹配算法，专门针对Dimoo商品
    """
    
    def dimoo_text_preprocess(text):
        """专门针对Dimoo商品的文本预处理"""
        if pd.isna(text):
            return ""
        
        text = str(text).lower()
        
        # 繁简转换
        text = convert_traditional_to_simplified(text)
        
        # 保留关键信息：数字、中文、英文、空格、点号
        text = re.sub(r'[^\w\s\.\-\u4e00-\u9fff]', '', text)
        
        # Dimoo特定的停用词
        dimoo_stop_words = {
            'pop', 'mart', 'dimoo', '系列', '款', '版', '正版', '全新', '未拆',
            '现货', '包邮', '特价', '优惠', '出售', '转让', '包正', '保证', '正品',
            '手办', '盲盒', '模型', '玩具', '公仔', '原价', '出', '换', '卖', '优惠'
        }
        
        words = text.split()
        filtered_words = [word for word in words if word not in dimoo_stop_words and len(word) > 0]
        
        if not filtered_words:
            simple_text = re.sub(r'[^\w\s\u4e00-\u9fff]', '', str(text))
            return simple_text.strip()
        
        return ' '.join(filtered_words)
    
    print("正在预处理Dimoo文本...")
    df_products['清洗名称'] = df_products['商品名称'].apply(dimoo_text_preprocess)
    df_official['清洗官方名称'] = df_official['官方名称'].apply(dimoo_text_preprocess)
    
    # 添加调试信息
    print("\n=== 预处理示例 ===")
    for i, (orig, cleaned) in enumerate(zip(df_products['商品名称'].head(5), df_products['清洗名称'].head(5))):
        print(f"原始: {orig} -> 清洗: {cleaned}")
    
    # 使用字符级别的TF-IDF
    vectorizer = TfidfVectorizer(
        analyzer='char_wb',
        ngram_range=(1, 3),
        min_df=1,
        max_features=10000,
        lowercase=False
    )
    
    # 合并所有文本进行训练
    all_texts = list(df_products['清洗名称']) + list(df_official['清洗官方名称'])
    vectorizer.fit(all_texts)
    
    products_tfidf = vectorizer.transform(df_products['清洗名称'])
    official_tfidf = vectorizer.transform(df_official['清洗官方名称'])
    
    # 计算相似度矩阵
    similarity_matrix = cosine_similarity(products_tfidf, official_tfidf)
    
    # 找到最佳匹配
    matches = []
    
    print(f"\n=== 匹配前数据检查 ===")
    print(f"待匹配商品数量: {len(df_products)}")
    print(f"官方商品数量: {len(df_official)}")
    
    for i, product_row in df_products.iterrows():
        product_name = product_row['商品名称']
        cleaned_name = product_row['清洗名称']
        
        # 关键词优先匹配 - 针对Dimoo系列
        matched_by_keyword = False
        for series_info in DIMOO_SERIES:
            series_simple = convert_traditional_to_simplified(series_info).lower()
            # 提取系列关键词
            keywords = re.findall(r'[\u4e00-\u9fff]+', series_simple)
            
            # 检查是否包含系列关键词
            if any(keyword in cleaned_name for keyword in keywords if len(keyword) > 1):
                # 找到对应的官方记录
                series_match = df_official[df_official['系列名称'] == series_info]
                if not series_match.empty:
                    official_match = series_match.iloc[0]
                    matches.append({
                        '商品名称': product_name,
                        '匹配官方名称': official_match['官方名称'],
                        '匹配系列': series_info,
                        '匹配图片URL': official_match.get('图片URL', ''),
                        '匹配度': 0.95,  # 高匹配度
                        '是否匹配成功': True,
                        '匹配方式': '关键词匹配'
                    })
                    print(f"✅ 通过关键词匹配: {product_name} -> {series_info}")
                    matched_by_keyword = True
                    break
        
        if matched_by_keyword:
            continue
        
        # TF-IDF匹配
        best_match_idx = np.argmax(similarity_matrix[i])
        best_score = similarity_matrix[i][best_match_idx]
        
        threshold = 0.15
        
        if best_score > threshold:
            official_match = df_official.iloc[best_match_idx]
            matches.append({
                '商品名称': product_name,
                '匹配官方名称': official_match['官方名称'],
                '匹配系列': official_match['系列名称'],
                '匹配图片URL': official_match.get('图片URL', ''),
                '匹配度': round(best_score, 3),
                '是否匹配成功': True,
                '匹配方式': 'TF-IDF匹配'
            })
        else:
            matches.append({
                '商品名称': product_name,
                '匹配官方名称': '未匹配到官方名称',
                '匹配系列': '未分类',
                '匹配图片URL': '',
                '匹配度': round(best_score, 3),
                '是否匹配成功': False,
                '匹配方式': '未匹配'
            })
    
    # 创建匹配结果的DataFrame
    df_matches = pd.DataFrame(matches)
    
    # 检查匹配结果是否有重复
    duplicate_matches = df_matches[df_matches.duplicated('商品名称', keep=False)]
    if not duplicate_matches.empty:
        print(f"⚠️  发现 {len(duplicate_matches)} 个重复匹配记录，进行去重...")
        df_matches = df_matches.drop_duplicates(subset=['商品名称'], keep='first')
    
    return df_matches

def remove_duplicate_data(df, file_description="数据"):
    """
    剔除商品名称、价格、发布用户、发布时间、商品链接和爬取时间完全一样的数据
    """
    print(f"\n=== 开始对 [{file_description}] 进行数据去重 ===")
    original_count = len(df)
    print(f"[{file_description}] 去重前数据量: {original_count}")
    
    # 定义去重的列
    duplicate_columns = ['商品名称', '价格', '发布用户', '发布时间', '商品链接', '爬取时间']
    
    # 检查哪些列实际存在于DataFrame中
    available_columns = [col for col in duplicate_columns if col in df.columns]
    print(f"[{file_description}] 用于去重的列: {available_columns}")
    
    if not available_columns:
        print(f"⚠️  警告: [{file_description}] 中没有找到任何指定的去重列，跳过去重")
        return df
    
    # 执行去重（保留第一条记录）
    df_deduplicated = df.drop_duplicates(subset=available_columns, keep='first')
    final_count = len(df_deduplicated)
    
    removed_count = original_count - final_count
    print(f"[{file_description}] 去重后数据量: {final_count}")
    print(f"[{file_description}] 移除的重复数据: {removed_count} 条")
    
    if original_count > 0:
        deduplication_rate = (removed_count / original_count * 100)
        print(f"[{file_description}] 去重率: {deduplication_rate:.2f}%")
    
    return df_deduplicated

def main():
    """
    Dimoo数据匹配主程序
    """
    # 读取Dimoo商品数据
    try:
        # 请根据您的实际文件路径修改
        df_products = pd.read_csv(r"D:\AImportant\留学\港城\course\Sem A\COM5507 Social Media Data\Group Project\Data\cleaned_dimoo.csv")
        print(f"✅ 加载了 {len(df_products)} 个Dimoo商品数据")
    except Exception as e:
        print(f"❌ 读取Dimoo商品数据失败: {e}")
        print("请检查文件路径是否正确")
        return
    
    # 数据去重
    print("\n" + "="*50)
    print("第一步：数据去重")
    print("="*50)
    df_products = remove_duplicate_data(df_products, "原始Dimoo数据")
    
    # 繁简转换
    print("\n" + "="*50)
    print("第二步：繁简转换")
    print("="*50)
    print("正在将商品名称由繁体转换为简体...")
    df_products['商品名称'] = df_products['商品名称'].apply(convert_traditional_to_simplified)
    print("✅ 商品名称繁简转换完成")
    
    # 显示转换后的示例
    print("\n=== 繁简转换示例 ===")
    for i, name in enumerate(df_products['商品名称'].head(5)):
        print(f"示例 {i+1}: {name}")
    
    # 创建官方数据
    print("\n" + "="*50)
    print("第三步：创建官方数据")
    print("="*50)
    official_products = create_dimoo_official_data()
    df_official = pd.DataFrame(official_products)
    print(f"✅ 创建了 {len(df_official)} 个官方Dimoo商品")
    
    # 显示官方系列
    print("\n=== Dimoo官方系列 ===")
    for i, series in enumerate(DIMOO_SERIES, 1):
        print(f"{i:2d}. {series}")
    
    # 进行匹配
    print("\n" + "="*50)
    print("第四步：商品匹配")
    print("="*50)
    df_matches = enhanced_dimoo_matching(df_products, df_official)
    
    # 合并结果
    df_final = df_products.merge(df_matches, on='商品名称', how='left')
    
    # 最终数据去重
    print("\n" + "="*50)
    print("第五步：最终数据去重")
    print("="*50)
    df_final = remove_duplicate_data(df_final, "最终Dimoo匹配结果")
    
    # 分析匹配结果
    match_stats = df_final['是否匹配成功'].value_counts()
    print(f"\n=== Dimoo匹配结果统计 ===")
    print(f"成功匹配: {match_stats.get(True, 0)} 件商品")
    print(f"未成功匹配: {match_stats.get(False, 0)} 件商品")
    if len(df_final) > 0:
        success_rate = match_stats.get(True, 0) / len(df_final) * 100
        print(f"匹配成功率: {success_rate:.1f}%")
    
    # 显示匹配方式统计
    if '匹配方式' in df_final.columns:
        method_stats = df_final[df_final['是否匹配成功'] == True]['匹配方式'].value_counts()
        print(f"\n=== 匹配方式统计 ===")
        for method, count in method_stats.items():
            print(f"{method}: {count}件")
    
    # 显示各系列统计
    if not df_final[df_final['是否匹配成功'] == True].empty:
        series_stats = df_final[df_final['是否匹配成功'] == True]['匹配系列'].value_counts()
        print(f"\n=== Dimoo各系列商品数量 ===")
        for series, count in series_stats.items():
            print(f"{series}: {count}件")
    
    # 保存结果
    final_save_path = r"D:\AImportant\留学\港城\course\Sem A\COM5507 Social Media Data\Group Project\Data\matched_dimoo.csv"
    if safe_save_dataframe(df_final, final_save_path):
        print(f"\n🎉 Dimoo匹配完成！结果已保存到: {final_save_path}")
    else:
        print(f"\n❌ 保存失败，请检查文件权限")

if __name__ == "__main__":
    main()
